# %%
import matplotlib.pyplot as plt
from razredi import Tocka
from jarvis_march import grid_peel_jarvis_enakomerna
from graham_scan import grid_peel_graham

# %%
graham = grid_peel_graham(3,3)
jarvis = grid_peel_jarvis_enakomerna(5,5)
print(jarvis)
#print(graham)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-154e567a6959> in <module>
#       1 graham = grid_peel_graham(3,3)
# ----> 2 jarvis = grid_peel_jarvis_enakomerna(5,5)
#       3 print(jarvis)
#       4 #print(graham)
#
# ~\Documents\faks\tretji letnik\financni praktikum\projekt\grid-peeling\jarvis_march.py in grid_peel_jarvis_enakomerna(m, n)
#      66     i = 0
#      67     while mreza:
# ---> 68         ch = jarvis_march(mreza)
#      69
#      70         nova = list(set(mreza) - set(ch))
#
# ~\Documents\faks\tretji letnik\financni praktikum\projekt\grid-peeling\jarvis_march.py in jarvis_march(seznam)
#      48                 continue
#      49
# ---> 50             d = seznam[i].smer_razlike(seznam[l],  seznam[q]) #poiščemo največji levi ovinek, v primeru kolinearnosti vključimo točko, ki je najdlje
#      51             if d > 0 or (d == 0 and seznam[i].razdalja(seznam[l]) > seznam[q].razdalja(seznam[l])):
#      52                 q = i
#
# ~\Documents\faks\tretji letnik\financni praktikum\projekt\grid-peeling\razredi.py in smer_razlike(self, other, another)
#      25     def smer_razlike(self, other, another):
#      26
# ---> 27         vekt_p = Tocka(self.x - other.x, self.y-other.y).vektorski_produkt(Tocka(another.x - other.x, another.y - other.y))
#      28
#      29         if vekt_p > 0:
#
# KeyboardInterrupt:

# %%
graham_1 = [(i.x, i.y) for i in graham[1][0]]
graham_2 = [(i.x, i.y) for i in graham[1][1]]
graham_3 = [(i.x, i.y) for i in graham[1][2]]

# %%
plt.plot(*zip(*graham_1), ".r-")
plt.plot(*zip(*graham_2), ".b-")
plt.plot(*zip(*graham_3), "-o")
